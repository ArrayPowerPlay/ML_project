# %% [markdown]
# # Decision Tree Regressor
#
# ## Mục tiêu
# - Xây dựng mô hình Decision Tree Regressor để dự đoán tuổi thọ trung bình
# - Sử dụng dữ liệu đã được tiền xử lý từ `data/processed/`
# - Tối ưu hóa siêu tham số bằng 5-Fold Cross-Validation
# - Đánh giá mô hình trên tập train
# - Lưu mô hình đã huấn luyện

# %% [markdown]
# ## Giới thiệu
#
# Mô hình cây quyết định phân chia không gian đặc trưng thành nhiều vùng và dự đoán bằng giá trị trung bình của từng vùng.
#
# ### **Ưu điểm:**
#
# - Dễ hiểu, trực quan.
#
# - Không cần chuẩn hóa dữ liệu.
#
# - Học được quan hệ phi tuyến.
#
# ### **Nhược điểm:**
#
# - Rất dễ overfitting.
#
# - Không ổn định: dễ bị ảnh hưởng bởi nhiễu/outliers.

# %% [markdown]
# ## Bước 1 - Import các thư viện cần thiết

# %%
# Thư viện cơ bản
import numpy as np
import pandas as pd
import os

# Thư viện sklearn cho mô hình và đánh giá
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import joblib

# %% [markdown]
# ## Bước 2 - Đọc dữ liệu đã tiền xử lý
#
# Đọc dữ liệu từ các file CSV đã được tiền xử lý và chia sẵn thành train/validation/test.

# %%
# Đọc dữ liệu
train_df = pd.read_csv('../data/processed/train.csv')

print("THÔNG TIN DỮ LIỆU")
print("="*60)
print(f"Kích thước tập train: {train_df.shape}")

# Hiển thị 5 dòng đầu của tập train
print("\n5 dòng đầu tiên của tập train (đã được chuẩn hóa):")
train_df.head()
# Out:
# THÔNG TIN DỮ LIỆU
# ============================================================
# Kích thước tập train: (3124, 13)
#
# 5 dòng đầu tiên của tập train (đã được chuẩn hóa):
#                 country_name country_code  year  population  pop_growth  \
# 0                    Denmark          DNK  2017   -0.203264   -0.418953
# 1  Korea, Dem. People's Rep.          PRK  2017   -0.056076   -0.530921
# 2                 Madagascar          MDG  2008   -0.091998    1.007790
# 3                     Greece          GRC  2018   -0.166799   -0.945727
# 4                South Sudan          SSD  2019   -0.169071    1.000983
#
#    life_expectancy  gdp_per_capita  gdp_growth  sanitation  electricity  \
# 0        81.102439        1.682694   -0.047741    1.673510     0.642797
# 1        73.034000       -0.412271    0.028651   -0.245951    -1.294730
# 2        61.992000       -0.607170    0.547296   -1.651029    -2.194047
# 3        81.787805        0.170491   -0.209157    1.356075     0.642797
# 4        58.129000       -0.412271    0.028651   -1.375450    -2.593358
#
#    water_access  co2_emissions  labor_force
# 0      0.754689       0.118599     0.069223
# 1      0.439985      -0.216848     2.087276
# 2     -2.540432      -0.528445     2.542268
# 3      0.754689       0.161554    -1.033944
# 4     -2.691194      -0.278341     1.279234

# %% [markdown]
# ## Bước 3 - Chuẩn bị dữ liệu cho mô hình
#
# Tách biến mục tiêu (`life_expectancy`) khỏi các đặc trưng. Loại bỏ các cột không cần thiết như `country_name`, `country_code`.

# %%
# Định nghĩa các cột dùng để dự đoán
feature_cols = [col for col in train_df.columns 
                if col not in ['life_expectancy', 'country_name', 'country_code']]

# Tách X và y cho từng tập
X_train = train_df[feature_cols]
y_train = train_df['life_expectancy']

print("THÔNG TIN CÁC TẬP DỮ LIỆU")
print("="*60)
print(f"Số lượng đặc trưng: {len(feature_cols)}")
print(f"\nCác đặc trưng được sử dụng:")
for i, col in enumerate(feature_cols, 1):
    print(f"  {i}. {col}")

print(f"\nKích thước X_train: {X_train.shape}")
print(f"Kích thước y_train: {y_train.shape}")
# Out:
# THÔNG TIN CÁC TẬP DỮ LIỆU
# ============================================================
# Số lượng đặc trưng: 10
#
# Các đặc trưng được sử dụng:
#   1. year
#   2. population
#   3. pop_growth
#   4. gdp_per_capita
#   5. gdp_growth
#   6. sanitation
#   7. electricity
#   8. water_access
#   9. co2_emissions
#   10. labor_force
#
# Kích thước X_train: (3124, 10)
# Kích thước y_train: (3124,)

# %% [markdown]
# ## Bước 4 - Xây dựng và huấn luyện mô hình Decision Tree

# %% [markdown]
# ### 4.1. Sử dụng RandomizedSearchCV với 5-Fold Cross-Validation để tìm kiếm siêu tham số tối ưu cho mô hình Decision Tree.

# %%
from scipy.stats import randint, uniform

# Định nghĩa không gian siêu tham số để tìm kiếm
param_distributions = {
    "max_depth": randint(2, 40),
    "min_samples_split": randint(2, 50),
    "min_samples_leaf": randint(1, 20),
    "max_features": uniform(0.3, 0.7),   # 0.3 → 1.0
    "min_weight_fraction_leaf": uniform(0.0, 0.1),
    "max_leaf_nodes": randint(10, 200),
    "min_impurity_decrease": uniform(0.0, 0.02)
}

# Tạo RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=DecisionTreeRegressor(random_state=42),
    param_distributions=param_distributions,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1,
    verbose=2,
    n_iter=60,
    random_state=42
)

# Thực hiện tìm kiếm
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV] END max_depth=30, max_features=0.4284043529063146, max_leaf_nodes=81, min_impurity_decrease=0.011973169683940733, min_samples_leaf=7, min_samples_split=20, min_weight_fraction_leaf=0.00999749158180029; total time=   0.0s
# [CV] END max_depth=30, max_features=0.4284043529063146, max_leaf_nodes=81, min_impurity_decrease=0.011973169683940733, min_samples_leaf=7, min_samples_split=20, min_weight_fraction_leaf=0.00999749158180029; total time=   0.0s
# [CV] END max_depth=4, max_features=0.9019582847154244, max_leaf_nodes=144, min_impurity_decrease=0.0034104824737458306, min_samples_leaf=7, min_samples_split=19, min_weight_fraction_leaf=0.09488855372533334; total time=   0.0s
# [CV] END max_depth=15, max_features=0.8658781436815228, max_leaf_nodes=18, min_impurity_decrease=0.0003193250444042839, min_samples_leaf=2, min_samples_split=21, min_weight_fraction_leaf=0.024102546602601173; total time=   0.0s
# [CV] END max_depth=12, max_features=0.9063233020424546, max_leaf_nodes=109, min_impurity_decrease=0.0028573363584388158, min_samples_leaf=3, min_samples_split=23, min_weight_fraction_leaf=0.005641157902710026; total time=   0.0s
# [CV] END max_depth=15, max_features=0.8658781436815228, max_leaf_nodes=18, min_impurity_decrease=0.0003193250444042839, min_samples_leaf=2, min_samples_split=21, min_weight_fraction_leaf=0.024102546602601173; total time=   0.0s
# [CV] END max_depth=15, max_features=0.8658781436815228, max_leaf_nodes=18, min_impurity_decrease=0.0003193250444042839, min_samples_leaf=2, min_samples_split=21, min_weight_fraction_leaf=0.024102546602601173; total time=   0.0s
# [CV] END max_depth=12, max_features=0.9063233020424546, max_leaf_nodes=109, min_impurity_decrease=0.0028573363584388158, min_samples_leaf=3, min_samples_split=23, min_weight_fraction_leaf=0.005641157902710026; total time=   0.0s
# [CV] END max_depth=15, max_features=0.8658781436815228, max_leaf_nodes=18, min_impurity_decrease=0.0003193250444042839, min_samples_leaf=2, min_samples_split=21, min_weight_fraction_leaf=0.024102546602601173; total time=   0.0s
# [CV] END max_depth=15, max_features=0.8658781436815228, max_leaf_nodes=18, min_impurity_decrease=0.0003193250444042839, min_samples_leaf=2, min_samples_split=21, min_weight_fraction_leaf=0.024102546602601173; total time=   0.0s
# [CV] END max_depth=8, max_features=0.7269976604478345, max_leaf_nodes=17, min_impurity_decrease=0.0006877704223043679, min_samples_leaf=14, min_samples_split=18, min_weight_fraction_leaf=0.02587799816000169; total time=   0.0s
# [CV] END max_depth=25, max_features=0.8827098485602951, max_leaf_nodes=47, min_impurity_decrease=1.5575316820286568e-05, min_samples_leaf=1, min_samples_split=13, min_weight_fraction_leaf=0.06116531604882809; total time=   0.0s
# [CV] END max_depth=30, max_features=0.4284043529063146, max_leaf_nodes=81, min_impurity_decrease=0.011973169683940733, min_samples_leaf=7, min_samples_split=20, min_weight_fraction_leaf=0.00999749158180029; total time=   0.0s
# [CV] END max_depth=8, max_features=0.7269976604478345, max_leaf_nodes=17, min_impurity_decrease=0.0006877704223043679, min_samples_leaf=14, min_samples_split=18, min_weight_fraction_leaf=0.02587799816000169; total time=   0.0s[CV] END max_depth=25, max_features=0.8827098485602951, max_leaf_nodes=47, min_impurity_decrease=1.5575316820286568e-05, min_samples_leaf=1, min_samples_split=13, min_weight_fraction_leaf=0.06116531604882809; total time=   0.0s
#
# [CV] END max_depth=26, max_features=0.5038603981386294, max_leaf_nodes=68, min_impurity_decrease=0.007997219434305109, min_samples_leaf=16, min_samples_split=16, min_weight_fraction_leaf=0.0456069984217036; total time=   0.0s
# [CV] END max_depth=8, max_features=0.7269976604478345, max_leaf_nodes=17, min_impurity_decrease=0.0006877704223043679, min_samples_leaf=14, min_samples_split=18, min_weight_fraction_leaf=0.02587799816000169; total time=   0.0s
# [CV] END max_depth=8, max_features=0.7269976604478345, max_leaf_nodes=17, min_impurity_decrease=0.0006877704223043679, min_samples_leaf=14, min_samples_split=18, min_weight_fraction_leaf=0.02587799816000169; total time=   0.0s
# [CV] END max_depth=5, max_features=0.5181977532625877, max_leaf_nodes=143, min_impurity_decrease=0.004158833257363777, min_samples_leaf=4, min_samples_split=30, min_weight_fraction_leaf=0.09695846277645587; total time=   0.0s
# [CV] END max_depth=8, max_features=0.7269976604478345, max_leaf_nodes=17, min_impurity_decrease=0.0006877704223043679, min_samples_leaf=14, min_samples_split=18, min_weight_fraction_leaf=0.02587799816000169; total time=   0.0s
# [CV] END max_depth=5, max_features=0.5181977532625877, max_leaf_nodes=143, min_impurity_decrease=0.004158833257363777, min_samples_leaf=4, min_samples_split=30, min_weight_fraction_leaf=0.09695846277645587; total time=   0.0s
# [CV] END max_depth=5, max_features=0.5181977532625877, max_leaf_nodes=143, min_impurity_decrease=0.004158833257363777, min_samples_leaf=4, min_samples_split=30, min_weight_fraction_leaf=0.09695846277645587; total time=   0.0s
# [CV] END max_depth=5, max_features=0.5181977532625877, max_leaf_nodes=143, min_impurity_decrease=0.004158833257363777, min_samples_leaf=4, min_samples_split=30, min_weight_fraction_leaf=0.09695846277645587; total time=   0.0s
# [CV] END max_depth=5, max_features=0.5181977532625877, max_leaf_nodes=143, min_impurity_decrease=0.004158833257363777, min_samples_leaf=4, min_samples_split=30, min_weight_fraction_leaf=0.09695846277645587; total time=   0.0s
# [CV] END max_depth=27, max_features=0.6148278933588359, max_leaf_nodes=199, min_impurity_decrease=0.018533177315875886, min_samples_leaf=16, min_samples_split=16, min_weight_fraction_leaf=0.00884925020519195; total time=   0.0s
# [CV] END max_depth=27, max_features=0.6148278933588359, max_leaf_nodes=199, min_impurity_decrease=0.018533177315875886, min_samples_leaf=16, min_samples_split=16, min_weight_fraction_leaf=0.00884925020519195; total time=   0.0s
# [CV] END max_depth=27, max_features=0.6148278933588359, max_leaf_nodes=199, min_impurity_decrease=0.018533177315875886, min_samples_leaf=16, min_samples_split=16, min_weight_fraction_leaf=0.00884925020519195; total time=   0.0s
# [CV] END max_depth=27, max_features=0.6148278933588359, max_leaf_nodes=199, min_impurity_decrease=0.018533177315875886, min_samples_leaf=16, min_samples_split=16, min_weight_fraction_leaf=0.00884925020519195; total time=   0.0s
# [CV] END max_depth=24, max_features=0.6645839820180766, max_leaf_nodes=199, min_impurity_decrease=0.006506606615265287, min_samples_leaf=16, min_samples_split=46, min_weight_fraction_leaf=0.02713490317738959; total time=   0.0s
# [CV] END max_depth=24, max_features=0.6645839820180766, max_leaf_nodes=199, min_impurity_decrease=0.006506606615265287, min_samples_leaf=16, min_samples_split=46, min_weight_fraction_leaf=0.02713490317738959; total time=   0.0s
# [CV] END max_depth=27, max_features=0.6148278933588359, max_leaf_nodes=199, min_impurity_decrease=0.018533177315875886, min_samples_leaf=16, min_samples_split=16, min_weight_fraction_leaf=0.00884925020519195; total time=   0.0s
# [CV] END max_depth=24, max_features=0.6645839820180766, max_leaf_nodes=199, min_impurity_decrease=0.006506606615265287, min_samples_leaf=16, min_samples_split=46, min_weight_fraction_leaf=0.02713490317738959; total time=   0.0s
# [CV] END max_depth=25, max_features=0.5497273286855124, max_leaf_nodes=197, min_impurity_decrease=0.01085392166316497, min_samples_leaf=9, min_samples_split=30, min_weight_fraction_leaf=0.08021969807540397; total time=   0.0s
# [CV] END max_depth=24, max_features=0.6645839820180766, max_leaf_nodes=199, min_impurity_decrease=0.006506606615265287, min_samples_leaf=16, min_samples_split=46, min_weight_fraction_leaf=0.02713490317738959; total time=   0.0s[CV] END max_depth=24, max_features=0.6645839820180766, max_leaf_nodes=199, min_impurity_decrease=0.006506606615265287, min_samples_leaf=16, min_samples_split=46, min_weight_fraction_leaf=0.02713490317738959; total time=   0.0s
#
# [CV] END max_depth=25, max_features=0.5497273286855124, max_leaf_nodes=197, min_impurity_decrease=0.01085392166316497, min_samples_leaf=9, min_samples_split=30, min_weight_fraction_leaf=0.08021969807540397; total time=   0.0s
# [CV] END max_depth=25, max_features=0.5497273286855124, max_leaf_nodes=197, min_impurity_decrease=0.01085392166316497, min_samples_leaf=9, min_samples_split=30, min_weight_fraction_leaf=0.08021969807540397; total time=   0.0s
# [CV] END max_depth=25, max_features=0.5497273286855124, max_leaf_nodes=197, min_impurity_decrease=0.01085392166316497, min_samples_leaf=9, min_samples_split=30, min_weight_fraction_leaf=0.08021969807540397; total time=   0.0s
# [CV] END max_depth=2, max_features=0.31094548471883576, max_leaf_nodes=18, min_impurity_decrease=0.015444895385933148, min_samples_leaf=12, min_samples_split=9, min_weight_fraction_leaf=0.00055221171236024; total time=   0.0s
# [CV] END max_depth=25, max_features=0.5497273286855124, max_leaf_nodes=197, min_impurity_decrease=0.01085392166316497, min_samples_leaf=9, min_samples_split=30, min_weight_fraction_leaf=0.08021969807540397; total time=   0.0s[CV] END max_depth=2, max_features=0.31094548471883576, max_leaf_nodes=18, min_impurity_decrease=0.015444895385933148, min_samples_leaf=12, min_samples_split=9, min_weight_fraction_leaf=0.00055221171236024; total time=   0.0s
#
# [CV] END max_depth=2, max_features=0.31094548471883576, max_leaf_nodes=18, min_impurity_decrease=0.015444895385933148, min_samples_leaf=12, min_samples_split=9, min_weight_fraction_leaf=0.00055221171236024; total time=   0.0s
# [CV] END max_depth=2, max_features=0.31094548471883576, max_leaf_nodes=18, min_impurity_decrease=0.015444895385933148, min_samples_leaf=12, min_samples_split=9, min_weight_fraction_leaf=0.00055221171236024; total time=   0.0s
# [CV] END max_depth=2, max_features=0.31094548471883576, max_leaf_nodes=18, min_impurity_decrease=0.015444895385933148, min_samples_leaf=12, min_samples_split=9, min_weight_fraction_leaf=0.00055221171236024; total time=   0.0s
# [CV] END max_depth=12, max_features=0.4391896828621636, max_leaf_nodes=145, min_impurity_decrease=0.014580143360819746, min_samples_leaf=1, min_samples_split=6, min_weight_fraction_leaf=0.0926300878513349; total time=   0.0s
# [CV] END max_depth=12, max_features=0.4391896828621636, max_leaf_nodes=145, min_impurity_decrease=0.014580143360819746, min_samples_leaf=1, min_samples_split=6, min_weight_fraction_leaf=0.0926300878513349; total time=   0.0s
# [CV] END max_depth=12, max_features=0.4391896828621636, max_leaf_nodes=145, min_impurity_decrease=0.014580143360819746, min_samples_leaf=1, min_samples_split=6, min_weight_fraction_leaf=0.0926300878513349; total time=   0.0s
# [CV] END max_depth=26, max_features=0.5038603981386294, max_leaf_nodes=68, min_impurity_decrease=0.007997219434305109, min_samples_leaf=16, min_samples_split=16, min_weight_fraction_leaf=0.0456069984217036; total time=   0.0s
# [CV] END max_depth=12, max_features=0.4391896828621636, max_leaf_nodes=145, min_impurity_decrease=0.014580143360819746, min_samples_leaf=1, min_samples_split=6, min_weight_fraction_leaf=0.0926300878513349; total time=   0.0s
# [CV] END max_depth=12, max_features=0.4391896828621636, max_leaf_nodes=145, min_impurity_decrease=0.014580143360819746, min_samples_leaf=1, min_samples_split=6, min_weight_fraction_leaf=0.0926300878513349; total time=   0.0s
# [CV] END max_depth=25, max_features=0.8827098485602951, max_leaf_nodes=47, min_impurity_decrease=1.5575316820286568e-05, min_samples_leaf=1, min_samples_split=13, min_weight_fraction_leaf=0.06116531604882809; total time=   0.0s
# [CV] END max_depth=29, max_features=0.9041723981129155, max_leaf_nodes=81, min_impurity_decrease=0.008989013482764067, min_samples_leaf=1, min_samples_split=49, min_weight_fraction_leaf=0.037081825219826635; total time=   0.0s
# [CV] END max_depth=29, max_features=0.9041723981129155, max_leaf_nodes=81, min_impurity_decrease=0.008989013482764067, min_samples_leaf=1, min_samples_split=49, min_weight_fraction_leaf=0.037081825219826635; total time=   0.0s
# [CV] END max_depth=4, max_features=0.9019582847154244, max_leaf_nodes=144, min_impurity_decrease=0.0034104824737458306, min_samples_leaf=7, min_samples_split=19, min_weight_fraction_leaf=0.09488855372533334; total time=   0.0s
# [CV] END max_depth=29, max_features=0.9041723981129155, max_leaf_nodes=81, min_impurity_decrease=0.008989013482764067, min_samples_leaf=1, min_samples_split=49, min_weight_fraction_leaf=0.037081825219826635; total time=   0.0s
# [CV] END max_depth=29, max_features=0.9041723981129155, max_leaf_nodes=81, min_impurity_decrease=0.008989013482764067, min_samples_leaf=1, min_samples_split=49, min_weight_fraction_leaf=0.037081825219826635; total time=   0.0s
# [CV] END max_depth=30, max_features=0.4284043529063146, max_leaf_nodes=81, min_impurity_decrease=0.011973169683940733, min_samples_leaf=7, min_samples_split=20, min_weight_fraction_leaf=0.00999749158180029; total time=   0.0s
# [CV] END max_depth=29, max_features=0.9041723981129155, max_leaf_nodes=81, min_impurity_decrease=0.008989013482764067, min_samples_leaf=1, min_samples_split=49, min_weight_fraction_leaf=0.037081825219826635; total time=   0.0s
# [CV] END max_depth=12, max_features=0.9063233020424546, max_leaf_nodes=109, min_impurity_decrease=0.0028573363584388158, min_samples_leaf=3, min_samples_split=23, min_weight_fraction_leaf=0.005641157902710026; total time=   0.0s[CV] END max_depth=25, max_features=0.7661456496322476, max_leaf_nodes=181, min_impurity_decrease=0.012751149427104263, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.038292687475378985; total time=   0.0s
#
# [CV] END max_depth=25, max_features=0.7661456496322476, max_leaf_nodes=181, min_impurity_decrease=0.012751149427104263, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.038292687475378985; total time=   0.0s
# [CV] END max_depth=25, max_features=0.7661456496322476, max_leaf_nodes=181, min_impurity_decrease=0.012751149427104263, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.038292687475378985; total time=   0.0s
# [CV] END max_depth=4, max_features=0.9019582847154244, max_leaf_nodes=144, min_impurity_decrease=0.0034104824737458306, min_samples_leaf=7, min_samples_split=19, min_weight_fraction_leaf=0.09488855372533334; total time=   0.0s
# [CV] END max_depth=25, max_features=0.7661456496322476, max_leaf_nodes=181, min_impurity_decrease=0.012751149427104263, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.038292687475378985; total time=   0.0s
# [CV] END max_depth=15, max_features=0.8942396769862586, max_leaf_nodes=14, min_impurity_decrease=0.011225543951389924, min_samples_leaf=14, min_samples_split=40, min_weight_fraction_leaf=0.004043358953843135; total time=   0.0s
# [CV] END max_depth=15, max_features=0.8942396769862586, max_leaf_nodes=14, min_impurity_decrease=0.011225543951389924, min_samples_leaf=14, min_samples_split=40, min_weight_fraction_leaf=0.004043358953843135; total time=   0.0s
# [CV] END max_depth=25, max_features=0.7661456496322476, max_leaf_nodes=181, min_impurity_decrease=0.012751149427104263, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.038292687475378985; total time=   0.0s
# [CV] END max_depth=16, max_features=0.5992787128509847, max_leaf_nodes=51, min_impurity_decrease=0.008786730037315402, min_samples_leaf=19, min_samples_split=33, min_weight_fraction_leaf=0.06364104112637804; total time=   0.0s
# [CV] END max_depth=15, max_features=0.8942396769862586, max_leaf_nodes=14, min_impurity_decrease=0.011225543951389924, min_samples_leaf=14, min_samples_split=40, min_weight_fraction_leaf=0.004043358953843135; total time=   0.0s
# [CV] END max_depth=30, max_features=0.4284043529063146, max_leaf_nodes=81, min_impurity_decrease=0.011973169683940733, min_samples_leaf=7, min_samples_split=20, min_weight_fraction_leaf=0.00999749158180029; total time=   0.0s
# [CV] END max_depth=15, max_features=0.8942396769862586, max_leaf_nodes=14, min_impurity_decrease=0.011225543951389924, min_samples_leaf=14, min_samples_split=40, min_weight_fraction_leaf=0.004043358953843135; total time=   0.0s
# [CV] END max_depth=15, max_features=0.8942396769862586, max_leaf_nodes=14, min_impurity_decrease=0.011225543951389924, min_samples_leaf=14, min_samples_split=40, min_weight_fraction_leaf=0.004043358953843135; total time=   0.0s
# [CV] END max_depth=16, max_features=0.5992787128509847, max_leaf_nodes=51, min_impurity_decrease=0.008786730037315402, min_samples_leaf=19, min_samples_split=33, min_weight_fraction_leaf=0.06364104112637804; total time=   0.0s
# [CV] END max_depth=16, max_features=0.5992787128509847, max_leaf_nodes=51, min_impurity_decrease=0.008786730037315402, min_samples_leaf=19, min_samples_split=33, min_weight_fraction_leaf=0.06364104112637804; total time=   0.0s
# [CV] END max_depth=16, max_features=0.5992787128509847, max_leaf_nodes=51, min_impurity_decrease=0.008786730037315402, min_samples_leaf=19, min_samples_split=33, min_weight_fraction_leaf=0.06364104112637804; total time=   0.0s
# [CV] END max_depth=16, max_features=0.5992787128509847, max_leaf_nodes=51, min_impurity_decrease=0.008786730037315402, min_samples_leaf=19, min_samples_split=33, min_weight_fraction_leaf=0.06364104112637804; total time=   0.0s
# [CV] END max_depth=33, max_features=0.7868612604982892, max_leaf_nodes=160, min_impurity_decrease=0.012088347585556346, min_samples_leaf=15, min_samples_split=44, min_weight_fraction_leaf=0.02030612247347694; total time=   0.0s
# [CV] END max_depth=33, max_features=0.7868612604982892, max_leaf_nodes=160, min_impurity_decrease=0.012088347585556346, min_samples_leaf=15, min_samples_split=44, min_weight_fraction_leaf=0.02030612247347694; total time=   0.0s
# [CV] END max_depth=33, max_features=0.7868612604982892, max_leaf_nodes=160, min_impurity_decrease=0.012088347585556346, min_samples_leaf=15, min_samples_split=44, min_weight_fraction_leaf=0.02030612247347694; total time=   0.0s
# [CV] END max_depth=33, max_features=0.7868612604982892, max_leaf_nodes=160, min_impurity_decrease=0.012088347585556346, min_samples_leaf=15, min_samples_split=44, min_weight_fraction_leaf=0.02030612247347694; total time=   0.0s
# [CV] END max_depth=14, max_features=0.35388593688015507, max_leaf_nodes=196, min_impurity_decrease=0.013895698660794091, min_samples_leaf=2, min_samples_split=43, min_weight_fraction_leaf=0.0808120379564417; total time=   0.0s
# [CV] END max_depth=14, max_features=0.35388593688015507, max_leaf_nodes=196, min_impurity_decrease=0.013895698660794091, min_samples_leaf=2, min_samples_split=43, min_weight_fraction_leaf=0.0808120379564417; total time=   0.0s
# [CV] END max_depth=12, max_features=0.9063233020424546, max_leaf_nodes=109, min_impurity_decrease=0.0028573363584388158, min_samples_leaf=3, min_samples_split=23, min_weight_fraction_leaf=0.005641157902710026; total time=   0.0s
# [CV] END max_depth=33, max_features=0.7868612604982892, max_leaf_nodes=160, min_impurity_decrease=0.012088347585556346, min_samples_leaf=15, min_samples_split=44, min_weight_fraction_leaf=0.02030612247347694; total time=   0.0s
# [CV] END max_depth=14, max_features=0.35388593688015507, max_leaf_nodes=196, min_impurity_decrease=0.013895698660794091, min_samples_leaf=2, min_samples_split=43, min_weight_fraction_leaf=0.0808120379564417; total time=   0.0s
# [CV] END max_depth=14, max_features=0.35388593688015507, max_leaf_nodes=196, min_impurity_decrease=0.013895698660794091, min_samples_leaf=2, min_samples_split=43, min_weight_fraction_leaf=0.0808120379564417; total time=   0.0s
# [CV] END max_depth=25, max_features=0.8827098485602951, max_leaf_nodes=47, min_impurity_decrease=1.5575316820286568e-05, min_samples_leaf=1, min_samples_split=13, min_weight_fraction_leaf=0.06116531604882809; total time=   0.0s
# [CV] END max_depth=14, max_features=0.35388593688015507, max_leaf_nodes=196, min_impurity_decrease=0.013895698660794091, min_samples_leaf=2, min_samples_split=43, min_weight_fraction_leaf=0.0808120379564417; total time=   0.0s
# [CV] END max_depth=7, max_features=0.6195741993380371, max_leaf_nodes=117, min_impurity_decrease=0.0037314011777207167, min_samples_leaf=11, min_samples_split=29, min_weight_fraction_leaf=0.03562978380769749; total time=   0.0s
# [CV] END max_depth=25, max_features=0.8827098485602951, max_leaf_nodes=47, min_impurity_decrease=1.5575316820286568e-05, min_samples_leaf=1, min_samples_split=13, min_weight_fraction_leaf=0.06116531604882809; total time=   0.0s
# [CV] END max_depth=7, max_features=0.6195741993380371, max_leaf_nodes=117, min_impurity_decrease=0.0037314011777207167, min_samples_leaf=11, min_samples_split=29, min_weight_fraction_leaf=0.03562978380769749; total time=   0.0s
# [CV] END max_depth=7, max_features=0.6195741993380371, max_leaf_nodes=117, min_impurity_decrease=0.0037314011777207167, min_samples_leaf=11, min_samples_split=29, min_weight_fraction_leaf=0.03562978380769749; total time=   0.0s
# [CV] END max_depth=34, max_features=0.49049257456924467, max_leaf_nodes=36, min_impurity_decrease=0.008542155772525126, min_samples_leaf=13, min_samples_split=42, min_weight_fraction_leaf=0.030478125815802906; total time=   0.0s
# [CV] END max_depth=34, max_features=0.49049257456924467, max_leaf_nodes=36, min_impurity_decrease=0.008542155772525126, min_samples_leaf=13, min_samples_split=42, min_weight_fraction_leaf=0.030478125815802906; total time=   0.0s
# [CV] END max_depth=7, max_features=0.6575231118042959, max_leaf_nodes=146, min_impurity_decrease=0.009696599427179665, min_samples_leaf=1, min_samples_split=43, min_weight_fraction_leaf=0.033761517140362796; total time=   0.0s
# [CV] END max_depth=34, max_features=0.49049257456924467, max_leaf_nodes=36, min_impurity_decrease=0.008542155772525126, min_samples_leaf=13, min_samples_split=42, min_weight_fraction_leaf=0.030478125815802906; total time=   0.0s
# [CV] END max_depth=7, max_features=0.6195741993380371, max_leaf_nodes=117, min_impurity_decrease=0.0037314011777207167, min_samples_leaf=11, min_samples_split=29, min_weight_fraction_leaf=0.03562978380769749; total time=   0.0s
# [CV] END max_depth=7, max_features=0.6195741993380371, max_leaf_nodes=117, min_impurity_decrease=0.0037314011777207167, min_samples_leaf=11, min_samples_split=29, min_weight_fraction_leaf=0.03562978380769749; total time=   0.0s
# [CV] END max_depth=16, max_features=0.4178037295210514, max_leaf_nodes=169, min_impurity_decrease=0.010375812434867323, min_samples_leaf=9, min_samples_split=13, min_weight_fraction_leaf=0.02517822958253642; total time=   0.0s
# [CV] END max_depth=34, max_features=0.49049257456924467, max_leaf_nodes=36, min_impurity_decrease=0.008542155772525126, min_samples_leaf=13, min_samples_split=42, min_weight_fraction_leaf=0.030478125815802906; total time=   0.0s
# [CV] END max_depth=26, max_features=0.5038603981386294, max_leaf_nodes=68, min_impurity_decrease=0.007997219434305109, min_samples_leaf=16, min_samples_split=16, min_weight_fraction_leaf=0.0456069984217036; total time=   0.0s[CV] END max_depth=34, max_features=0.49049257456924467, max_leaf_nodes=36, min_impurity_decrease=0.008542155772525126, min_samples_leaf=13, min_samples_split=42, min_weight_fraction_leaf=0.030478125815802906; total time=   0.0s
#
# [CV] END max_depth=16, max_features=0.4178037295210514, max_leaf_nodes=169, min_impurity_decrease=0.010375812434867323, min_samples_leaf=9, min_samples_split=13, min_weight_fraction_leaf=0.02517822958253642; total time=   0.0s
# [CV] END max_depth=7, max_features=0.6575231118042959, max_leaf_nodes=146, min_impurity_decrease=0.009696599427179665, min_samples_leaf=1, min_samples_split=43, min_weight_fraction_leaf=0.033761517140362796; total time=   0.0s
# [CV] END max_depth=16, max_features=0.4178037295210514, max_leaf_nodes=169, min_impurity_decrease=0.010375812434867323, min_samples_leaf=9, min_samples_split=13, min_weight_fraction_leaf=0.02517822958253642; total time=   0.0s
# [CV] END max_depth=12, max_features=0.9063233020424546, max_leaf_nodes=109, min_impurity_decrease=0.0028573363584388158, min_samples_leaf=3, min_samples_split=23, min_weight_fraction_leaf=0.005641157902710026; total time=   0.0s
# [CV] END max_depth=7, max_features=0.6575231118042959, max_leaf_nodes=146, min_impurity_decrease=0.009696599427179665, min_samples_leaf=1, min_samples_split=43, min_weight_fraction_leaf=0.033761517140362796; total time=   0.0s
# [CV] END max_depth=7, max_features=0.6575231118042959, max_leaf_nodes=146, min_impurity_decrease=0.009696599427179665, min_samples_leaf=1, min_samples_split=43, min_weight_fraction_leaf=0.033761517140362796; total time=   0.0s
# [CV] END max_depth=24, max_features=0.495052524965628, max_leaf_nodes=138, min_impurity_decrease=0.004791237813339448, min_samples_leaf=2, min_samples_split=45, min_weight_fraction_leaf=0.04477831645730917; total time=   0.0s
# [CV] END max_depth=3, max_features=0.7985894129471094, max_leaf_nodes=110, min_impurity_decrease=0.005696809887549352, min_samples_leaf=17, min_samples_split=3, min_weight_fraction_leaf=0.05026790232288615; total time=   0.0s
# [CV] END max_depth=3, max_features=0.7985894129471094, max_leaf_nodes=110, min_impurity_decrease=0.005696809887549352, min_samples_leaf=17, min_samples_split=3, min_weight_fraction_leaf=0.05026790232288615; total time=   0.0s
# [CV] END max_depth=24, max_features=0.495052524965628, max_leaf_nodes=138, min_impurity_decrease=0.004791237813339448, min_samples_leaf=2, min_samples_split=45, min_weight_fraction_leaf=0.04477831645730917; total time=   0.0s
# [CV] END max_depth=16, max_features=0.4178037295210514, max_leaf_nodes=169, min_impurity_decrease=0.010375812434867323, min_samples_leaf=9, min_samples_split=13, min_weight_fraction_leaf=0.02517822958253642; total time=   0.0s
# [CV] END max_depth=24, max_features=0.495052524965628, max_leaf_nodes=138, min_impurity_decrease=0.004791237813339448, min_samples_leaf=2, min_samples_split=45, min_weight_fraction_leaf=0.04477831645730917; total time=   0.0s
# [CV] END max_depth=16, max_features=0.4178037295210514, max_leaf_nodes=169, min_impurity_decrease=0.010375812434867323, min_samples_leaf=9, min_samples_split=13, min_weight_fraction_leaf=0.02517822958253642; total time=   0.0s
# [CV] END max_depth=3, max_features=0.7985894129471094, max_leaf_nodes=110, min_impurity_decrease=0.005696809887549352, min_samples_leaf=17, min_samples_split=3, min_weight_fraction_leaf=0.05026790232288615; total time=   0.0s
# [CV] END max_depth=7, max_features=0.6575231118042959, max_leaf_nodes=146, min_impurity_decrease=0.009696599427179665, min_samples_leaf=1, min_samples_split=43, min_weight_fraction_leaf=0.033761517140362796; total time=   0.0s
# [CV] END max_depth=7, max_features=0.4694386900580503, max_leaf_nodes=77, min_impurity_decrease=0.001617066526654305, min_samples_leaf=17, min_samples_split=39, min_weight_fraction_leaf=0.03677831327192532; total time=   0.0s
# [CV] END max_depth=24, max_features=0.495052524965628, max_leaf_nodes=138, min_impurity_decrease=0.004791237813339448, min_samples_leaf=2, min_samples_split=45, min_weight_fraction_leaf=0.04477831645730917; total time=   0.0s
# [CV] END max_depth=3, max_features=0.7985894129471094, max_leaf_nodes=110, min_impurity_decrease=0.005696809887549352, min_samples_leaf=17, min_samples_split=3, min_weight_fraction_leaf=0.05026790232288615; total time=   0.0s
# [CV] END max_depth=7, max_features=0.4694386900580503, max_leaf_nodes=77, min_impurity_decrease=0.001617066526654305, min_samples_leaf=17, min_samples_split=39, min_weight_fraction_leaf=0.03677831327192532; total time=   0.0s
# [CV] END max_depth=24, max_features=0.495052524965628, max_leaf_nodes=138, min_impurity_decrease=0.004791237813339448, min_samples_leaf=2, min_samples_split=45, min_weight_fraction_leaf=0.04477831645730917; total time=   0.0s
# [CV] END max_depth=3, max_features=0.7985894129471094, max_leaf_nodes=110, min_impurity_decrease=0.005696809887549352, min_samples_leaf=17, min_samples_split=3, min_weight_fraction_leaf=0.05026790232288615; total time=   0.0s
# [CV] END max_depth=7, max_features=0.4694386900580503, max_leaf_nodes=77, min_impurity_decrease=0.001617066526654305, min_samples_leaf=17, min_samples_split=39, min_weight_fraction_leaf=0.03677831327192532; total time=   0.0s
# [CV] END max_depth=7, max_features=0.4694386900580503, max_leaf_nodes=77, min_impurity_decrease=0.001617066526654305, min_samples_leaf=17, min_samples_split=39, min_weight_fraction_leaf=0.03677831327192532; total time=   0.0s
# [CV] END max_depth=35, max_features=0.7434707975326262, max_leaf_nodes=148, min_impurity_decrease=0.016328637464387678, min_samples_leaf=16, min_samples_split=34, min_weight_fraction_leaf=0.015071754396542947; total time=   0.0s
# [CV] END max_depth=7, max_features=0.4694386900580503, max_leaf_nodes=77, min_impurity_decrease=0.001617066526654305, min_samples_leaf=17, min_samples_split=39, min_weight_fraction_leaf=0.03677831327192532; total time=   0.0s
# [CV] END max_depth=20, max_features=0.5440661911042105, max_leaf_nodes=61, min_impurity_decrease=0.01881046528979208, min_samples_leaf=8, min_samples_split=40, min_weight_fraction_leaf=0.09367299887367346; total time=   0.0s
# [CV] END max_depth=2, max_features=0.7729830819274965, max_leaf_nodes=194, min_impurity_decrease=0.0022694704248117817, min_samples_leaf=10, min_samples_split=36, min_weight_fraction_leaf=0.022855002179729966; total time=   0.0s
# [CV] END max_depth=7, max_features=0.7870689647536173, max_leaf_nodes=12, min_impurity_decrease=0.011817858863764836, min_samples_leaf=4, min_samples_split=20, min_weight_fraction_leaf=0.07111495324380178; total time=   0.0s
# [CV] END max_depth=20, max_features=0.5440661911042105, max_leaf_nodes=61, min_impurity_decrease=0.01881046528979208, min_samples_leaf=8, min_samples_split=40, min_weight_fraction_leaf=0.09367299887367346; total time=   0.0s
# [CV] END max_depth=20, max_features=0.5440661911042105, max_leaf_nodes=61, min_impurity_decrease=0.01881046528979208, min_samples_leaf=8, min_samples_split=40, min_weight_fraction_leaf=0.09367299887367346; total time=   0.0s
# [CV] END max_depth=7, max_features=0.7870689647536173, max_leaf_nodes=12, min_impurity_decrease=0.011817858863764836, min_samples_leaf=4, min_samples_split=20, min_weight_fraction_leaf=0.07111495324380178; total time=   0.0s
# [CV] END max_depth=2, max_features=0.7729830819274965, max_leaf_nodes=194, min_impurity_decrease=0.0022694704248117817, min_samples_leaf=10, min_samples_split=36, min_weight_fraction_leaf=0.022855002179729966; total time=   0.0s
# [CV] END max_depth=35, max_features=0.7434707975326262, max_leaf_nodes=148, min_impurity_decrease=0.016328637464387678, min_samples_leaf=16, min_samples_split=34, min_weight_fraction_leaf=0.015071754396542947; total time=   0.0s
# [CV] END max_depth=35, max_features=0.7434707975326262, max_leaf_nodes=148, min_impurity_decrease=0.016328637464387678, min_samples_leaf=16, min_samples_split=34, min_weight_fraction_leaf=0.015071754396542947; total time=   0.0s
# [CV] END max_depth=35, max_features=0.7434707975326262, max_leaf_nodes=148, min_impurity_decrease=0.016328637464387678, min_samples_leaf=16, min_samples_split=34, min_weight_fraction_leaf=0.015071754396542947; total time=   0.0s
# [CV] END max_depth=17, max_features=0.872055540140851, max_leaf_nodes=69, min_impurity_decrease=0.00521658349660818, min_samples_leaf=1, min_samples_split=49, min_weight_fraction_leaf=0.09654193512887937; total time=   0.0s
# [CV] END max_depth=2, max_features=0.7729830819274965, max_leaf_nodes=194, min_impurity_decrease=0.0022694704248117817, min_samples_leaf=10, min_samples_split=36, min_weight_fraction_leaf=0.022855002179729966; total time=   0.0s
# [CV] END max_depth=17, max_features=0.872055540140851, max_leaf_nodes=69, min_impurity_decrease=0.00521658349660818, min_samples_leaf=1, min_samples_split=49, min_weight_fraction_leaf=0.09654193512887937; total time=   0.0s[CV] END max_depth=2, max_features=0.7729830819274965, max_leaf_nodes=194, min_impurity_decrease=0.0022694704248117817, min_samples_leaf=10, min_samples_split=36, min_weight_fraction_leaf=0.022855002179729966; total time=   0.0s
#
# [CV] END max_depth=20, max_features=0.5440661911042105, max_leaf_nodes=61, min_impurity_decrease=0.01881046528979208, min_samples_leaf=8, min_samples_split=40, min_weight_fraction_leaf=0.09367299887367346; total time=   0.0s
# [CV] END max_depth=20, max_features=0.5440661911042105, max_leaf_nodes=61, min_impurity_decrease=0.01881046528979208, min_samples_leaf=8, min_samples_split=40, min_weight_fraction_leaf=0.09367299887367346; total time=   0.0s
# [CV] END max_depth=7, max_features=0.7870689647536173, max_leaf_nodes=12, min_impurity_decrease=0.011817858863764836, min_samples_leaf=4, min_samples_split=20, min_weight_fraction_leaf=0.07111495324380178; total time=   0.0s
# [CV] END max_depth=17, max_features=0.872055540140851, max_leaf_nodes=69, min_impurity_decrease=0.00521658349660818, min_samples_leaf=1, min_samples_split=49, min_weight_fraction_leaf=0.09654193512887937; total time=   0.0s
# [CV] END max_depth=2, max_features=0.7729830819274965, max_leaf_nodes=194, min_impurity_decrease=0.0022694704248117817, min_samples_leaf=10, min_samples_split=36, min_weight_fraction_leaf=0.022855002179729966; total time=   0.0s
# [CV] END max_depth=7, max_features=0.7870689647536173, max_leaf_nodes=12, min_impurity_decrease=0.011817858863764836, min_samples_leaf=4, min_samples_split=20, min_weight_fraction_leaf=0.07111495324380178; total time=   0.0s
# [CV] END max_depth=6, max_features=0.9302926400143312, max_leaf_nodes=18, min_impurity_decrease=0.005577427051843637, min_samples_leaf=19, min_samples_split=49, min_weight_fraction_leaf=0.0846661142238306; total time=   0.0s
# [CV] END max_depth=6, max_features=0.9302926400143312, max_leaf_nodes=18, min_impurity_decrease=0.005577427051843637, min_samples_leaf=19, min_samples_split=49, min_weight_fraction_leaf=0.0846661142238306; total time=   0.0s
# [CV] END max_depth=17, max_features=0.872055540140851, max_leaf_nodes=69, min_impurity_decrease=0.00521658349660818, min_samples_leaf=1, min_samples_split=49, min_weight_fraction_leaf=0.09654193512887937; total time=   0.0s
# [CV] END max_depth=7, max_features=0.7870689647536173, max_leaf_nodes=12, min_impurity_decrease=0.011817858863764836, min_samples_leaf=4, min_samples_split=20, min_weight_fraction_leaf=0.07111495324380178; total time=   0.0s
# [CV] END max_depth=21, max_features=0.920960496985582, max_leaf_nodes=129, min_impurity_decrease=0.017755401975219198, min_samples_leaf=11, min_samples_split=9, min_weight_fraction_leaf=0.07853406511139437; total time=   0.0s
# [CV] END max_depth=21, max_features=0.920960496985582, max_leaf_nodes=129, min_impurity_decrease=0.017755401975219198, min_samples_leaf=11, min_samples_split=9, min_weight_fraction_leaf=0.07853406511139437; total time=   0.0s
# [CV] END max_depth=4, max_features=0.9019582847154244, max_leaf_nodes=144, min_impurity_decrease=0.0034104824737458306, min_samples_leaf=7, min_samples_split=19, min_weight_fraction_leaf=0.09488855372533334; total time=   0.0s
# [CV] END max_depth=21, max_features=0.920960496985582, max_leaf_nodes=129, min_impurity_decrease=0.017755401975219198, min_samples_leaf=11, min_samples_split=9, min_weight_fraction_leaf=0.07853406511139437; total time=   0.0s
# [CV] END max_depth=17, max_features=0.872055540140851, max_leaf_nodes=69, min_impurity_decrease=0.00521658349660818, min_samples_leaf=1, min_samples_split=49, min_weight_fraction_leaf=0.09654193512887937; total time=   0.0s
# [CV] END max_depth=35, max_features=0.7434707975326262, max_leaf_nodes=148, min_impurity_decrease=0.016328637464387678, min_samples_leaf=16, min_samples_split=34, min_weight_fraction_leaf=0.015071754396542947; total time=   0.0s
# [CV] END max_depth=19, max_features=0.6399296275103585, max_leaf_nodes=172, min_impurity_decrease=0.01303922519005201, min_samples_leaf=9, min_samples_split=37, min_weight_fraction_leaf=0.07121792213475359; total time=   0.0s
# [CV] END max_depth=19, max_features=0.6399296275103585, max_leaf_nodes=172, min_impurity_decrease=0.01303922519005201, min_samples_leaf=9, min_samples_split=37, min_weight_fraction_leaf=0.07121792213475359; total time=   0.0s
# [CV] END max_depth=19, max_features=0.6399296275103585, max_leaf_nodes=172, min_impurity_decrease=0.01303922519005201, min_samples_leaf=9, min_samples_split=37, min_weight_fraction_leaf=0.07121792213475359; total time=   0.0s
# [CV] END max_depth=6, max_features=0.9302926400143312, max_leaf_nodes=18, min_impurity_decrease=0.005577427051843637, min_samples_leaf=19, min_samples_split=49, min_weight_fraction_leaf=0.0846661142238306; total time=   0.0s
# [CV] END max_depth=34, max_features=0.6457256006284042, max_leaf_nodes=57, min_impurity_decrease=0.014929828102360484, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.07209399242521293; total time=   0.0s
# [CV] END max_depth=6, max_features=0.9302926400143312, max_leaf_nodes=18, min_impurity_decrease=0.005577427051843637, min_samples_leaf=19, min_samples_split=49, min_weight_fraction_leaf=0.0846661142238306; total time=   0.0s
# [CV] END max_depth=6, max_features=0.9302926400143312, max_leaf_nodes=18, min_impurity_decrease=0.005577427051843637, min_samples_leaf=19, min_samples_split=49, min_weight_fraction_leaf=0.0846661142238306; total time=   0.0s
# [CV] END max_depth=34, max_features=0.6457256006284042, max_leaf_nodes=57, min_impurity_decrease=0.014929828102360484, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.07209399242521293; total time=   0.0s
# [CV] END max_depth=34, max_features=0.6797781613884295, max_leaf_nodes=196, min_impurity_decrease=0.007354316061188671, min_samples_leaf=14, min_samples_split=31, min_weight_fraction_leaf=0.09730105547524456; total time=   0.0s
# [CV] END max_depth=34, max_features=0.6797781613884295, max_leaf_nodes=196, min_impurity_decrease=0.007354316061188671, min_samples_leaf=14, min_samples_split=31, min_weight_fraction_leaf=0.09730105547524456; total time=   0.0s
# [CV] END max_depth=21, max_features=0.920960496985582, max_leaf_nodes=129, min_impurity_decrease=0.017755401975219198, min_samples_leaf=11, min_samples_split=9, min_weight_fraction_leaf=0.07853406511139437; total time=   0.0s
# [CV] END max_depth=21, max_features=0.920960496985582, max_leaf_nodes=129, min_impurity_decrease=0.017755401975219198, min_samples_leaf=11, min_samples_split=9, min_weight_fraction_leaf=0.07853406511139437; total time=   0.0s
# [CV] END max_depth=19, max_features=0.6399296275103585, max_leaf_nodes=172, min_impurity_decrease=0.01303922519005201, min_samples_leaf=9, min_samples_split=37, min_weight_fraction_leaf=0.07121792213475359; total time=   0.0s
# [CV] END max_depth=19, max_features=0.6399296275103585, max_leaf_nodes=172, min_impurity_decrease=0.01303922519005201, min_samples_leaf=9, min_samples_split=37, min_weight_fraction_leaf=0.07121792213475359; total time=   0.0s
# [CV] END max_depth=21, max_features=0.7064806350055182, max_leaf_nodes=121, min_impurity_decrease=0.002029430857320642, min_samples_leaf=3, min_samples_split=26, min_weight_fraction_leaf=0.0005061583846218687; total time=   0.0s
# [CV] END max_depth=34, max_features=0.6457256006284042, max_leaf_nodes=57, min_impurity_decrease=0.014929828102360484, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.07209399242521293; total time=   0.0s
# [CV] END max_depth=34, max_features=0.6457256006284042, max_leaf_nodes=57, min_impurity_decrease=0.014929828102360484, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.07209399242521293; total time=   0.0s
# [CV] END max_depth=34, max_features=0.6797781613884295, max_leaf_nodes=196, min_impurity_decrease=0.007354316061188671, min_samples_leaf=14, min_samples_split=31, min_weight_fraction_leaf=0.09730105547524456; total time=   0.0s
# [CV] END max_depth=34, max_features=0.6797781613884295, max_leaf_nodes=196, min_impurity_decrease=0.007354316061188671, min_samples_leaf=14, min_samples_split=31, min_weight_fraction_leaf=0.09730105547524456; total time=   0.0s
# [CV] END max_depth=34, max_features=0.6797781613884295, max_leaf_nodes=196, min_impurity_decrease=0.007354316061188671, min_samples_leaf=14, min_samples_split=31, min_weight_fraction_leaf=0.09730105547524456; total time=   0.0s
# [CV] END max_depth=34, max_features=0.6457256006284042, max_leaf_nodes=57, min_impurity_decrease=0.014929828102360484, min_samples_leaf=8, min_samples_split=8, min_weight_fraction_leaf=0.07209399242521293; total time=   0.0s
# [CV] END max_depth=21, max_features=0.7064806350055182, max_leaf_nodes=121, min_impurity_decrease=0.002029430857320642, min_samples_leaf=3, min_samples_split=26, min_weight_fraction_leaf=0.0005061583846218687; total time=   0.0s
# [CV] END max_depth=21, max_features=0.7064806350055182, max_leaf_nodes=121, min_impurity_decrease=0.002029430857320642, min_samples_leaf=3, min_samples_split=26, min_weight_fraction_leaf=0.0005061583846218687; total time=   0.0s
# [CV] END max_depth=9, max_features=0.741797038198084, max_leaf_nodes=30, min_impurity_decrease=0.010052741862103842, min_samples_leaf=15, min_samples_split=34, min_weight_fraction_leaf=0.019524298779804453; total time=   0.0s
# [CV] END max_depth=7, max_features=0.559111090178811, max_leaf_nodes=46, min_impurity_decrease=0.018566371251754508, min_samples_leaf=17, min_samples_split=47, min_weight_fraction_leaf=0.09666548190436697; total time=   0.0s
# [CV] END max_depth=4, max_features=0.9019582847154244, max_leaf_nodes=144, min_impurity_decrease=0.0034104824737458306, min_samples_leaf=7, min_samples_split=19, min_weight_fraction_leaf=0.09488855372533334; total time=   0.0s
# [CV] END max_depth=20, max_features=0.7004029394464282, max_leaf_nodes=58, min_impurity_decrease=0.0008720754350886751, min_samples_leaf=12, min_samples_split=29, min_weight_fraction_leaf=0.0469944513990943; total time=   0.0s
# [CV] END max_depth=20, max_features=0.7004029394464282, max_leaf_nodes=58, min_impurity_decrease=0.0008720754350886751, min_samples_leaf=12, min_samples_split=29, min_weight_fraction_leaf=0.0469944513990943; total time=   0.0s
# [CV] END max_depth=21, max_features=0.7064806350055182, max_leaf_nodes=121, min_impurity_decrease=0.002029430857320642, min_samples_leaf=3, min_samples_split=26, min_weight_fraction_leaf=0.0005061583846218687; total time=   0.0s
# [CV] END max_depth=7, max_features=0.559111090178811, max_leaf_nodes=46, min_impurity_decrease=0.018566371251754508, min_samples_leaf=17, min_samples_split=47, min_weight_fraction_leaf=0.09666548190436697; total time=   0.0s
# [CV] END max_depth=9, max_features=0.741797038198084, max_leaf_nodes=30, min_impurity_decrease=0.010052741862103842, min_samples_leaf=15, min_samples_split=34, min_weight_fraction_leaf=0.019524298779804453; total time=   0.0s
# [CV] END max_depth=34, max_features=0.3956349320094201, max_leaf_nodes=185, min_impurity_decrease=0.011056399538158155, min_samples_leaf=10, min_samples_split=27, min_weight_fraction_leaf=0.08101133946791808; total time=   0.0s
# [CV] END max_depth=9, max_features=0.741797038198084, max_leaf_nodes=30, min_impurity_decrease=0.010052741862103842, min_samples_leaf=15, min_samples_split=34, min_weight_fraction_leaf=0.019524298779804453; total time=   0.0s
# [CV] END max_depth=36, max_features=0.986232108601232, max_leaf_nodes=125, min_impurity_decrease=0.005888977841391714, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.016949274668609248; total time=   0.0s
# [CV] END max_depth=20, max_features=0.7004029394464282, max_leaf_nodes=58, min_impurity_decrease=0.0008720754350886751, min_samples_leaf=12, min_samples_split=29, min_weight_fraction_leaf=0.0469944513990943; total time=   0.0s
# [CV] END max_depth=7, max_features=0.559111090178811, max_leaf_nodes=46, min_impurity_decrease=0.018566371251754508, min_samples_leaf=17, min_samples_split=47, min_weight_fraction_leaf=0.09666548190436697; total time=   0.0s
# [CV] END max_depth=33, max_features=0.7698004617768354, max_leaf_nodes=160, min_impurity_decrease=0.002801680304730481, min_samples_leaf=10, min_samples_split=3, min_weight_fraction_leaf=0.03225507642386005; total time=   0.0s
# [CV] END max_depth=35, max_features=0.3657873578886083, max_leaf_nodes=95, min_impurity_decrease=0.006563053349494639, min_samples_leaf=17, min_samples_split=43, min_weight_fraction_leaf=0.08226005606596583; total time=   0.0s
# [CV] END max_depth=26, max_features=0.5762840267666305, max_leaf_nodes=63, min_impurity_decrease=0.013920595933499461, min_samples_leaf=8, min_samples_split=47, min_weight_fraction_leaf=0.009717649377076854; total time=   0.0s
# [CV] END max_depth=36, max_features=0.986232108601232, max_leaf_nodes=125, min_impurity_decrease=0.005888977841391714, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.016949274668609248; total time=   0.0s
# [CV] END max_depth=9, max_features=0.741797038198084, max_leaf_nodes=30, min_impurity_decrease=0.010052741862103842, min_samples_leaf=15, min_samples_split=34, min_weight_fraction_leaf=0.019524298779804453; total time=   0.0s
# [CV] END max_depth=26, max_features=0.7280595976059763, max_leaf_nodes=69, min_impurity_decrease=0.010226847977218756, min_samples_leaf=4, min_samples_split=46, min_weight_fraction_leaf=0.019427395351204226; total time=   0.0s
# [CV] END max_depth=34, max_features=0.3956349320094201, max_leaf_nodes=185, min_impurity_decrease=0.011056399538158155, min_samples_leaf=10, min_samples_split=27, min_weight_fraction_leaf=0.08101133946791808; total time=   0.0s
# [CV] END max_depth=7, max_features=0.3361772048180254, max_leaf_nodes=125, min_impurity_decrease=0.00822707810113357, min_samples_leaf=3, min_samples_split=41, min_weight_fraction_leaf=0.07260913337226615; total time=   0.0s
# [CV] END max_depth=20, max_features=0.7004029394464282, max_leaf_nodes=58, min_impurity_decrease=0.0008720754350886751, min_samples_leaf=12, min_samples_split=29, min_weight_fraction_leaf=0.0469944513990943; total time=   0.0s
# [CV] END max_depth=7, max_features=0.559111090178811, max_leaf_nodes=46, min_impurity_decrease=0.018566371251754508, min_samples_leaf=17, min_samples_split=47, min_weight_fraction_leaf=0.09666548190436697; total time=   0.0s
# [CV] END max_depth=38, max_features=0.6655702820383631, max_leaf_nodes=62, min_impurity_decrease=0.005430858316394838, min_samples_leaf=12, min_samples_split=6, min_weight_fraction_leaf=0.045726516161372854; total time=   0.0s
# [CV] END max_depth=35, max_features=0.3657873578886083, max_leaf_nodes=95, min_impurity_decrease=0.006563053349494639, min_samples_leaf=17, min_samples_split=43, min_weight_fraction_leaf=0.08226005606596583; total time=   0.0s
# [CV] END max_depth=21, max_features=0.7064806350055182, max_leaf_nodes=121, min_impurity_decrease=0.002029430857320642, min_samples_leaf=3, min_samples_split=26, min_weight_fraction_leaf=0.0005061583846218687; total time=   0.0s
# [CV] END max_depth=20, max_features=0.7004029394464282, max_leaf_nodes=58, min_impurity_decrease=0.0008720754350886751, min_samples_leaf=12, min_samples_split=29, min_weight_fraction_leaf=0.0469944513990943; total time=   0.0s
# [CV] END max_depth=9, max_features=0.7913768140803923, max_leaf_nodes=153, min_impurity_decrease=0.0010153706207879387, min_samples_leaf=19, min_samples_split=24, min_weight_fraction_leaf=0.0027616771873704704; total time=   0.0s
# [CV] END max_depth=26, max_features=0.5762840267666305, max_leaf_nodes=63, min_impurity_decrease=0.013920595933499461, min_samples_leaf=8, min_samples_split=47, min_weight_fraction_leaf=0.009717649377076854; total time=   0.0s
# [CV] END max_depth=7, max_features=0.3361772048180254, max_leaf_nodes=125, min_impurity_decrease=0.00822707810113357, min_samples_leaf=3, min_samples_split=41, min_weight_fraction_leaf=0.07260913337226615; total time=   0.0s
# [CV] END max_depth=33, max_features=0.7698004617768354, max_leaf_nodes=160, min_impurity_decrease=0.002801680304730481, min_samples_leaf=10, min_samples_split=3, min_weight_fraction_leaf=0.03225507642386005; total time=   0.0s
# ...
# [CV] END max_depth=2, max_features=0.9684056964642358, max_leaf_nodes=78, min_impurity_decrease=0.012234414924687045, min_samples_leaf=3, min_samples_split=13, min_weight_fraction_leaf=0.05660372104940763; total time=   0.0s
# [CV] END max_depth=14, max_features=0.9786758069799113, max_leaf_nodes=115, min_impurity_decrease=0.006459129458824919, min_samples_leaf=17, min_samples_split=20, min_weight_fraction_leaf=0.04389714207056361; total time=   0.0s
# [CV] END max_depth=14, max_features=0.9786758069799113, max_leaf_nodes=115, min_impurity_decrease=0.006459129458824919, min_samples_leaf=17, min_samples_split=20, min_weight_fraction_leaf=0.04389714207056361; total time=   0.0s[CV] END max_depth=6, max_features=0.6319216803611276, max_leaf_nodes=185, min_impurity_decrease=0.01613825954101559, min_samples_leaf=4, min_samples_split=34, min_weight_fraction_leaf=0.04646738129396114; total time=   0.0s
# [CV] END max_depth=38, max_features=0.5789533140781613, max_leaf_nodes=19, min_impurity_decrease=0.01898291463182772, min_samples_leaf=4, min_samples_split=35, min_weight_fraction_leaf=0.026089362334171397; total time=   0.0s
#
# [CV] END max_depth=34, max_features=0.3956349320094201, max_leaf_nodes=185, min_impurity_decrease=0.011056399538158155, min_samples_leaf=10, min_samples_split=27, min_weight_fraction_leaf=0.08101133946791808; total time=   0.0s
# [CV] END max_depth=2, max_features=0.9684056964642358, max_leaf_nodes=78, min_impurity_decrease=0.012234414924687045, min_samples_leaf=3, min_samples_split=13, min_weight_fraction_leaf=0.05660372104940763; total time=   0.0s
# [CV] END max_depth=26, max_features=0.7280595976059763, max_leaf_nodes=69, min_impurity_decrease=0.010226847977218756, min_samples_leaf=4, min_samples_split=46, min_weight_fraction_leaf=0.019427395351204226; total time=   0.0s
# [CV] END max_depth=38, max_features=0.3841152534639495, max_leaf_nodes=38, min_impurity_decrease=0.002321452810138325, min_samples_leaf=5, min_samples_split=48, min_weight_fraction_leaf=0.004072880231897014; total time=   0.0s
# [CV] END max_depth=9, max_features=0.7913768140803923, max_leaf_nodes=153, min_impurity_decrease=0.0010153706207879387, min_samples_leaf=19, min_samples_split=24, min_weight_fraction_leaf=0.0027616771873704704; total time=   0.0s
# [CV] END max_depth=33, max_features=0.7698004617768354, max_leaf_nodes=160, min_impurity_decrease=0.002801680304730481, min_samples_leaf=10, min_samples_split=3, min_weight_fraction_leaf=0.03225507642386005; total time=   0.0s
# [CV] END max_depth=26, max_features=0.5762840267666305, max_leaf_nodes=63, min_impurity_decrease=0.013920595933499461, min_samples_leaf=8, min_samples_split=47, min_weight_fraction_leaf=0.009717649377076854; total time=   0.0s
# [CV] END max_depth=35, max_features=0.3657873578886083, max_leaf_nodes=95, min_impurity_decrease=0.006563053349494639, min_samples_leaf=17, min_samples_split=43, min_weight_fraction_leaf=0.08226005606596583; total time=   0.0s
# [CV] END max_depth=2, max_features=0.6096465608117732, max_leaf_nodes=105, min_impurity_decrease=0.01098453329412241, min_samples_leaf=16, min_samples_split=26, min_weight_fraction_leaf=0.06601973767177313; total time=   0.0s
# [CV] END max_depth=2, max_features=0.6096465608117732, max_leaf_nodes=105, min_impurity_decrease=0.01098453329412241, min_samples_leaf=16, min_samples_split=26, min_weight_fraction_leaf=0.06601973767177313; total time=   0.0s[CV] END max_depth=27, max_features=0.31774552039082027, max_leaf_nodes=126, min_impurity_decrease=0.0016174593323439535, min_samples_leaf=9, min_samples_split=13, min_weight_fraction_leaf=0.04089529444142699; total time=   0.0s
#
# [CV] END max_depth=11, max_features=0.7381019409999654, max_leaf_nodes=195, min_impurity_decrease=0.010020797678305184, min_samples_leaf=5, min_samples_split=46, min_weight_fraction_leaf=0.01629344270814297; total time=   0.0s
# [CV] END max_depth=38, max_features=0.6655702820383631, max_leaf_nodes=62, min_impurity_decrease=0.005430858316394838, min_samples_leaf=12, min_samples_split=6, min_weight_fraction_leaf=0.045726516161372854; total time=   0.0s
# [CV] END max_depth=2, max_features=0.9684056964642358, max_leaf_nodes=78, min_impurity_decrease=0.012234414924687045, min_samples_leaf=3, min_samples_split=13, min_weight_fraction_leaf=0.05660372104940763; total time=   0.0s
# [CV] END max_depth=25, max_features=0.9607241231925299, max_leaf_nodes=11, min_impurity_decrease=0.0005302262108324363, min_samples_leaf=12, min_samples_split=36, min_weight_fraction_leaf=0.06432882184423531; total time=   0.0s
# [CV] END max_depth=35, max_features=0.3657873578886083, max_leaf_nodes=95, min_impurity_decrease=0.006563053349494639, min_samples_leaf=17, min_samples_split=43, min_weight_fraction_leaf=0.08226005606596583; total time=   0.0s
# [CV] END max_depth=11, max_features=0.7381019409999654, max_leaf_nodes=195, min_impurity_decrease=0.010020797678305184, min_samples_leaf=5, min_samples_split=46, min_weight_fraction_leaf=0.01629344270814297; total time=   0.0s
# [CV] END max_depth=38, max_features=0.5789533140781613, max_leaf_nodes=19, min_impurity_decrease=0.01898291463182772, min_samples_leaf=4, min_samples_split=35, min_weight_fraction_leaf=0.026089362334171397; total time=   0.0s
# [CV] END max_depth=38, max_features=0.3841152534639495, max_leaf_nodes=38, min_impurity_decrease=0.002321452810138325, min_samples_leaf=5, min_samples_split=48, min_weight_fraction_leaf=0.004072880231897014; total time=   0.0s[CV] END max_depth=34, max_features=0.8678429237152021, max_leaf_nodes=180, min_impurity_decrease=0.018829296175530502, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.09611905638239143; total time=   0.0s
#
# [CV] END max_depth=6, max_features=0.6319216803611276, max_leaf_nodes=185, min_impurity_decrease=0.01613825954101559, min_samples_leaf=4, min_samples_split=34, min_weight_fraction_leaf=0.04646738129396114; total time=   0.0s
# [CV] END max_depth=25, max_features=0.9607241231925299, max_leaf_nodes=11, min_impurity_decrease=0.0005302262108324363, min_samples_leaf=12, min_samples_split=36, min_weight_fraction_leaf=0.06432882184423531; total time=   0.0s
# [CV] END max_depth=34, max_features=0.8678429237152021, max_leaf_nodes=180, min_impurity_decrease=0.018829296175530502, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.09611905638239143; total time=   0.0s
# [CV] END max_depth=27, max_features=0.31774552039082027, max_leaf_nodes=126, min_impurity_decrease=0.0016174593323439535, min_samples_leaf=9, min_samples_split=13, min_weight_fraction_leaf=0.04089529444142699; total time=   0.0s
# [CV] END max_depth=36, max_features=0.986232108601232, max_leaf_nodes=125, min_impurity_decrease=0.005888977841391714, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.016949274668609248; total time=   0.0s
# [CV] END max_depth=6, max_features=0.6319216803611276, max_leaf_nodes=185, min_impurity_decrease=0.01613825954101559, min_samples_leaf=4, min_samples_split=34, min_weight_fraction_leaf=0.04646738129396114; total time=   0.0s
# [CV] END max_depth=2, max_features=0.6096465608117732, max_leaf_nodes=105, min_impurity_decrease=0.01098453329412241, min_samples_leaf=16, min_samples_split=26, min_weight_fraction_leaf=0.06601973767177313; total time=   0.0s
# [CV] END max_depth=14, max_features=0.9786758069799113, max_leaf_nodes=115, min_impurity_decrease=0.006459129458824919, min_samples_leaf=17, min_samples_split=20, min_weight_fraction_leaf=0.04389714207056361; total time=   0.0s
# [CV] END max_depth=34, max_features=0.8678429237152021, max_leaf_nodes=180, min_impurity_decrease=0.018829296175530502, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.09611905638239143; total time=   0.0s
# [CV] END max_depth=26, max_features=0.7280595976059763, max_leaf_nodes=69, min_impurity_decrease=0.010226847977218756, min_samples_leaf=4, min_samples_split=46, min_weight_fraction_leaf=0.019427395351204226; total time=   0.0s
# [CV] END max_depth=2, max_features=0.9684056964642358, max_leaf_nodes=78, min_impurity_decrease=0.012234414924687045, min_samples_leaf=3, min_samples_split=13, min_weight_fraction_leaf=0.05660372104940763; total time=   0.0s
# [CV] END max_depth=33, max_features=0.7698004617768354, max_leaf_nodes=160, min_impurity_decrease=0.002801680304730481, min_samples_leaf=10, min_samples_split=3, min_weight_fraction_leaf=0.03225507642386005; total time=   0.0s
# [CV] END max_depth=38, max_features=0.5789533140781613, max_leaf_nodes=19, min_impurity_decrease=0.01898291463182772, min_samples_leaf=4, min_samples_split=35, min_weight_fraction_leaf=0.026089362334171397; total time=   0.0s
# [CV] END max_depth=34, max_features=0.8678429237152021, max_leaf_nodes=180, min_impurity_decrease=0.018829296175530502, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.09611905638239143; total time=   0.0s
# [CV] END max_depth=26, max_features=0.5762840267666305, max_leaf_nodes=63, min_impurity_decrease=0.013920595933499461, min_samples_leaf=8, min_samples_split=47, min_weight_fraction_leaf=0.009717649377076854; total time=   0.0s
# [CV] END max_depth=25, max_features=0.9607241231925299, max_leaf_nodes=11, min_impurity_decrease=0.0005302262108324363, min_samples_leaf=12, min_samples_split=36, min_weight_fraction_leaf=0.06432882184423531; total time=   0.0s
# [CV] END max_depth=11, max_features=0.7381019409999654, max_leaf_nodes=195, min_impurity_decrease=0.010020797678305184, min_samples_leaf=5, min_samples_split=46, min_weight_fraction_leaf=0.01629344270814297; total time=   0.0s
# [CV] END max_depth=2, max_features=0.6096465608117732, max_leaf_nodes=105, min_impurity_decrease=0.01098453329412241, min_samples_leaf=16, min_samples_split=26, min_weight_fraction_leaf=0.06601973767177313; total time=   0.0s
# [CV] END max_depth=6, max_features=0.6319216803611276, max_leaf_nodes=185, min_impurity_decrease=0.01613825954101559, min_samples_leaf=4, min_samples_split=34, min_weight_fraction_leaf=0.04646738129396114; total time=   0.0s
# [CV] END max_depth=11, max_features=0.44467905191372176, max_leaf_nodes=38, min_impurity_decrease=0.0013872260175033092, min_samples_leaf=14, min_samples_split=3, min_weight_fraction_leaf=0.003896313231023363; total time=   0.0s
# [CV] END max_depth=9, max_features=0.7913768140803923, max_leaf_nodes=153, min_impurity_decrease=0.0010153706207879387, min_samples_leaf=19, min_samples_split=24, min_weight_fraction_leaf=0.0027616771873704704; total time=   0.0s
# [CV] END max_depth=11, max_features=0.44467905191372176, max_leaf_nodes=38, min_impurity_decrease=0.0013872260175033092, min_samples_leaf=14, min_samples_split=3, min_weight_fraction_leaf=0.003896313231023363; total time=   0.0s
# [CV] END max_depth=34, max_features=0.8678429237152021, max_leaf_nodes=180, min_impurity_decrease=0.018829296175530502, min_samples_leaf=3, min_samples_split=2, min_weight_fraction_leaf=0.09611905638239143; total time=   0.0s
# [CV] END max_depth=38, max_features=0.3841152534639495, max_leaf_nodes=38, min_impurity_decrease=0.002321452810138325, min_samples_leaf=5, min_samples_split=48, min_weight_fraction_leaf=0.004072880231897014; total time=   0.0s
# [CV] END max_depth=11, max_features=0.44467905191372176, max_leaf_nodes=38, min_impurity_decrease=0.0013872260175033092, min_samples_leaf=14, min_samples_split=3, min_weight_fraction_leaf=0.003896313231023363; total time=   0.0s
# [CV] END max_depth=6, max_features=0.6319216803611276, max_leaf_nodes=185, min_impurity_decrease=0.01613825954101559, min_samples_leaf=4, min_samples_split=34, min_weight_fraction_leaf=0.04646738129396114; total time=   0.0s
# [CV] END max_depth=11, max_features=0.44467905191372176, max_leaf_nodes=38, min_impurity_decrease=0.0013872260175033092, min_samples_leaf=14, min_samples_split=3, min_weight_fraction_leaf=0.003896313231023363; total time=   0.0s
# [CV] END max_depth=38, max_features=0.5789533140781613, max_leaf_nodes=19, min_impurity_decrease=0.01898291463182772, min_samples_leaf=4, min_samples_split=35, min_weight_fraction_leaf=0.026089362334171397; total time=   0.0s
# [CV] END max_depth=11, max_features=0.44467905191372176, max_leaf_nodes=38, min_impurity_decrease=0.0013872260175033092, min_samples_leaf=14, min_samples_split=3, min_weight_fraction_leaf=0.003896313231023363; total time=   0.0s
# [CV] END max_depth=14, max_features=0.9786758069799113, max_leaf_nodes=115, min_impurity_decrease=0.006459129458824919, min_samples_leaf=17, min_samples_split=20, min_weight_fraction_leaf=0.04389714207056361; total time=   0.0s
# [CV] END max_depth=11, max_features=0.7381019409999654, max_leaf_nodes=195, min_impurity_decrease=0.010020797678305184, min_samples_leaf=5, min_samples_split=46, min_weight_fraction_leaf=0.01629344270814297; total time=   0.0s
# [CV] END max_depth=36, max_features=0.986232108601232, max_leaf_nodes=125, min_impurity_decrease=0.005888977841391714, min_samples_leaf=1, min_samples_split=4, min_weight_fraction_leaf=0.016949274668609248; total time=   0.0s
# [CV] END max_depth=38, max_features=0.5789533140781613, max_leaf_nodes=19, min_impurity_decrease=0.01898291463182772, min_samples_leaf=4, min_samples_split=35, min_weight_fraction_leaf=0.026089362334171397; total time=   0.0s
# [CV] END max_depth=38, max_features=0.3841152534639495, max_leaf_nodes=38, min_impurity_decrease=0.002321452810138325, min_samples_leaf=5, min_samples_split=48, min_weight_fraction_leaf=0.004072880231897014; total time=   0.0s
# [CV] END max_depth=25, max_features=0.9607241231925299, max_leaf_nodes=11, min_impurity_decrease=0.0005302262108324363, min_samples_leaf=12, min_samples_split=36, min_weight_fraction_leaf=0.06432882184423531; total time=   0.0s
# [CV] END max_depth=9, max_features=0.7913768140803923, max_leaf_nodes=153, min_impurity_decrease=0.0010153706207879387, min_samples_leaf=19, min_samples_split=24, min_weight_fraction_leaf=0.0027616771873704704; total time=   0.0s
# [CV] END max_depth=11, max_features=0.7381019409999654, max_leaf_nodes=195, min_impurity_decrease=0.010020797678305184, min_samples_leaf=5, min_samples_split=46, min_weight_fraction_leaf=0.01629344270814297; total time=   0.0s
# [CV] END max_depth=25, max_features=0.9607241231925299, max_leaf_nodes=11, min_impurity_decrease=0.0005302262108324363, min_samples_leaf=12, min_samples_split=36, min_weight_fraction_leaf=0.06432882184423531; total time=   0.0s
# [CV] END max_depth=26, max_features=0.5038603981386294, max_leaf_nodes=68, min_impurity_decrease=0.007997219434305109, min_samples_leaf=16, min_samples_split=16, min_weight_fraction_leaf=0.0456069984217036; total time=   0.0s
# [CV] END max_depth=26, max_features=0.5038603981386294, max_leaf_nodes=68, min_impurity_decrease=0.007997219434305109, min_samples_leaf=16, min_samples_split=16, min_weight_fraction_leaf=0.0456069984217036; total time=   0.0s
# RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42),
#                    n_iter=60, n_jobs=-1,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x796ff9dd9100>,
#                                         'max_features': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x796ff83fd6d0>,
#                                         'max_leaf_nodes': <scipy.stats._distn_infrastructure.r...
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x796ff83fd5b0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x796ff8c22660>,
#                                         'min_weight_fraction_leaf': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x796ff9dd9220>},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=2)

# %% [markdown]
# ### 4.2. Hiển thị siêu tham số tối ưu và đánh giá hiệu suất của mô hình tốt nhất.

# %%
# Lấy mô hình tốt nhất và tham số tối ưu
best_dt = random_search.best_estimator_
best_params = random_search.best_params_

print("SIÊU THAM SỐ TỐI ƯU")
print("="*60)
for param, value in best_params.items():
    print(f"  {param:20s}: {value}")

# Thông tin về cây tối ưu
print(f"\nĐộ sâu của cây tối ưu: {best_dt.get_depth()}")
print(f"Số lượng lá: {best_dt.get_n_leaves()}")
# Out:
# SIÊU THAM SỐ TỐI ƯU
# ============================================================
#   max_depth           : 21
#   max_features        : 0.7064806350055182
#   max_leaf_nodes      : 121
#   min_impurity_decrease: 0.002029430857320642
#   min_samples_leaf    : 3
#   min_samples_split   : 26
#   min_weight_fraction_leaf: 0.0005061583846218687
#
# Độ sâu của cây tối ưu: 14
# Số lượng lá: 121

# %% [markdown]
# ### 4.3. Đánh giá mô hình tối ưu trên tập train

# %%
y_pred = best_dt.predict(X_train)

# Tính toán các metrics cho tập train
train_mae = mean_absolute_error(y_train, y_pred)
train_rmse = np.sqrt(mean_squared_error(y_train, y_pred))
train_r2 = r2_score(y_train, y_pred)

print("KẾT QUẢ MÔ HÌNH TỐI ƯU")
print("="*60)
print("Model: Decision Tree:")
print(f"RMSE loss: {train_rmse:.3f}")
print(f"MAE loss: {train_mae:.3f}")
print(f"R2 score: {train_r2:.3f}")
# Out:
# KẾT QUẢ MÔ HÌNH TỐI ƯU
# ============================================================
# Model: Decision Tree:
# RMSE loss: 2.230
# MAE loss: 1.635
# R2 score: 0.936

# %% [markdown]
# ### 4.4. Lưu mô hình Decision Tree đã tối ưu vào file để sử dụng sau này.

# %%
# Tạo thư mục lưu model nếu chưa có
os.makedirs('../models/3_decision_tree', exist_ok=True)

# Lưu mô hình
model_path = '../models/3_decision_tree/decision_tree.pkl'
joblib.dump(best_dt, model_path)
# Out:
# ['../models/3_decision_tree/decision_tree.pkl']

# %% [markdown]
# ## Kết luận
#
# ### Tổng kết:
# - Mô hình Decision Tree đã được xây dựng và tối ưu hóa thành công
# - RandomizedSearchCV với 5-Fold CV đã tìm được bộ siêu tham số tối ưu
# - Mô hình được đánh giá dựa trên 3 metrics: MAE, RMSE và R2
